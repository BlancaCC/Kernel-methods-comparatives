# %%
import os
import pandas as pd

database = 'CPU_SMALL'


if database == 'CPU_SMALL':
    size_of_dataset = 8192	
elif database == 'abalone':
    size_of_dataset = 4177
else:
    size_of_dataset = 4177

path = '/Users/blancacanocamarero/repositorios/TFM/Kernel-methods-comparatives/Basic-measures/'
directory = path + f'results/{database}/accuracy_time_stats'  # Replace this with the path to your directory
verbose_path = path + f'results/{database}/verboses'
analysis_files = path + f'analysis/{database}'
plot_path = f'./{database}/plot/'


## columns names 
percent_column = 'percent'
n_components_column = 'n_components' 


# Get a list of all files in the directory
files = [file for file in os.listdir(directory) if os.path.isfile(os.path.join(directory, file))]

# Now 'files' contains a list of the names of all files in the directory
print(files)

# Separate files with "classification" in their name
ridge_files = [file for file in files if "ridge" in file]
ridge_files.sort()

# Separate other files
svm_files = [file for file in files if file not in ridge_files]
svm_files.sort()
compute_percent = lambda row: row[n_components_column] / size_of_dataset * 100
damping_formula = lambda accuracy, time : accuracy / time *100
damping_column = 'damping'
score_column, time_column = ('Mean Score in test', 'Mean Training Time')

def damping_df(df):
    df[damping_column] = damping_formula(df[score_column],df[time_column])
    return df

 
# Create a DataFrame for ridge files
ridge_data = pd.DataFrame()
ridge_list = []
ridge_list_names = []
ridge_data_verbose = pd.DataFrame()
for file in ridge_files:
    # mean
    file_path = os.path.join(directory, file)
    data = pd.read_csv(file_path)  # Assuming the files are in CSV format, adjust as needed
    data[percent_column] = data.apply(compute_percent, axis=1)

    data = damping_df(data)
    ridge_list_names.append(file)
    data = data.sort_values(by=n_components_column)
    data['File'] = file  # Add a column to identify the file 
    ridge_data = pd.concat([ridge_data, data], ignore_index=True)
    ridge_list.append(data)

    # verbose
    file_path = os.path.join(verbose_path, file)
    data = pd.read_csv(file_path)  # Assuming the files are in CSV format, adjust as needed
    data[percent_column] = data.apply(compute_percent, axis=1)
    data = data.sort_values(by=n_components_column)
    data['File'] = file  # Add a column to identify the file
    ridge_data_verbose = pd.concat([ridge_data_verbose, data], ignore_index=True) 


svm_data = pd.DataFrame()
svm_data_verbose = pd.DataFrame()
svm_list = []
svm_list_names = []
for file in svm_files:
    file_path = os.path.join(directory, file)
    data = pd.read_csv(file_path)  # Assuming the files are in CSV format, adjust as needed
    data[percent_column] = data.apply(compute_percent, axis=1)
    data = data.sort_values(by=n_components_column)
    data = damping_df(data)
    data['File'] = file  # Add a column to identify the file
    data = data.sort_values(by=n_components_column)
    svm_data = pd.concat([svm_data, data], ignore_index=True)
    svm_list.append(data)
    svm_list_names.append(file)
    # verbose
    file_path = os.path.join(verbose_path, file)
    data = pd.read_csv(file_path)  # Assuming the files are in CSV format, adjust as needed
    data[percent_column] = data.apply(compute_percent, axis=1)
    data = data.sort_values(by=n_components_column)
    data['File'] = file  # Add a column to identify the file
    svm_data_verbose = pd.concat([svm_data_verbose, data], ignore_index=True)

print('Ridge files')
print(ridge_list_names)
print('SvM files')
print(svm_list_names)
svm_data
# Out:
# ['Nystrom_and_SVR_CPU_SMALL_cv_5.csv', 'Kernel_SVR_CPU_SMALL_cv_5.csv', 'Random_Fourier_features_and_ridge_regression_CPU_SMALL_cv_5.csv', 'Random_Fourier_features_and_SVR_CPU_SMALL_cv_5.csv', 'Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv', 'Kernel_ridge_regression_CPU_SMALL_cv_5.csv']
# Ridge files
# ['Kernel_ridge_regression_CPU_SMALL_cv_5.csv', 'Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv', 'Random_Fourier_features_and_ridge_regression_CPU_SMALL_cv_5.csv']
# SvM files
# ['Kernel_SVR_CPU_SMALL_cv_5.csv', 'Nystrom_and_SVR_CPU_SMALL_cv_5.csv', 'Random_Fourier_features_and_SVR_CPU_SMALL_cv_5.csv']
#        percent  n_components  Mean Score in test  Std Score in test  \
# 0   100.000000          8192            0.972103           0.000753
# 1     0.488281            40            0.894745           0.013943
# 2     0.988770            81            0.948742           0.004452
# 3     1.989746           163            0.963716           0.002223
# 4     3.991699           327            0.969728           0.001641
# 5     5.993652           491            0.971193           0.003168
# 6     7.995605           655            0.971498           0.002255
# 7     9.997559           819            0.971240           0.004616
# 8    13.989258          1146            0.972438           0.002630
# 9    15.991211          1310            0.971613           0.003583
# 10   17.993164          1474            0.972432           0.002752
# 11   19.995117          1638            0.972363           0.001573
# 12   25.000000          2048            0.972479           0.003034
# 13    0.012207             1            0.019867           0.346985
# 14    0.024414             2            0.155836           0.295053
# 15    0.036621             3            0.249300           0.157143
# 16    0.061035             5           -0.052139           0.203302
# 17    0.085449             7           -0.022313           0.715662
# 18    0.109863             9            0.204634           0.356075
# 19    0.134277            11           -0.571896           1.668300
# 20    0.183105            15           -0.031152           0.444131
# 21    0.207520            17            0.467098           0.244270
# 22    0.231934            19            0.503649           0.388562
# 23    0.256348            21            0.249860           0.687303
# 24    0.317383            26            0.694681           0.144695
#
#     Mean Training Time  Std Training Time  Mean Best Score in CV  \
# 0             5.309447           0.183302               0.971035
# 1             3.134119           1.893874               0.874513
# 2             5.893051           0.211876               0.945386
# 3             7.222983           0.253452               0.957070
# 4            10.240944           0.309475               0.967186
# 5            12.719765           0.201547               0.969241
# 6            15.257145           0.357140               0.969104
# 7            17.805814           0.314949               0.969806
# 8            23.375512           0.322730               0.970612
# 9            26.645865           0.325142               0.970735
# 10           29.046731           0.184934               0.971383
# 11           32.982823           0.294592               0.971169
# 12           45.799095           0.228838               0.970600
# 13            0.005263           0.001600               0.187150
# 14            0.003696           0.000347               0.264851
# 15            0.003978           0.000755               0.318297
# 16            0.003649           0.000144               0.522902
# 17            0.003648           0.000106               0.526496
# 18            0.006413           0.003418               0.670674
# 19            0.003484           0.000061               0.398553
# 20            0.003553           0.000012               0.594307
# 21            0.003629           0.000070               0.569958
# 22            0.004503           0.000898               0.609374
# 23            0.004252           0.001064               0.654539
# 24            0.006277           0.001733               0.722058
#
#     Std Best Score in CV       damping  \
# 0               0.000609     18.308937
# 1               0.007410     28.548536
# 2               0.002072     16.099340
# 3               0.003008     13.342350
# 4               0.001419      9.469123
# 5               0.001341      7.635305
# 6               0.001188      6.367493
# 7               0.001811      5.454622
# 8               0.000781      4.160073
# 9               0.001454      3.646394
# 10              0.001419      3.347819
# 11              0.001190      2.948089
# 12              0.001669      2.123360
# 13              0.045208    377.477972
# 14              0.106915   4216.731171
# 15              0.059331   6267.602157
# 16              0.074332  -1428.920657
# 17              0.129181   -611.674625
# 18              0.065424   3191.059395
# 19              0.078644 -16412.631650
# 20              0.018267   -876.696282
# 21              0.085895  12870.320588
# 22              0.117423  11183.537136
# 23              0.110120   5876.855561
# 24              0.039622  11067.465711
#
#                                                  File
# 0                       Kernel_SVR_CPU_SMALL_cv_5.csv
# 1                  Nystrom_and_SVR_CPU_SMALL_cv_5.csv
# 2                  Nystrom_and_SVR_CPU_SMALL_cv_5.csv
# 3                  Nystrom_and_SVR_CPU_SMALL_cv_5.csv
# 4                  Nystrom_and_SVR_CPU_SMALL_cv_5.csv
# 5                  Nystrom_and_SVR_CPU_SMALL_cv_5.csv
# 6                  Nystrom_and_SVR_CPU_SMALL_cv_5.csv
# 7                  Nystrom_and_SVR_CPU_SMALL_cv_5.csv
# 8                  Nystrom_and_SVR_CPU_SMALL_cv_5.csv
# 9                  Nystrom_and_SVR_CPU_SMALL_cv_5.csv
# 10                 Nystrom_and_SVR_CPU_SMALL_cv_5.csv
# 11                 Nystrom_and_SVR_CPU_SMALL_cv_5.csv
# 12                 Nystrom_and_SVR_CPU_SMALL_cv_5.csv
# 13  Random_Fourier_features_and_SVR_CPU_SMALL_cv_5...
# 14  Random_Fourier_features_and_SVR_CPU_SMALL_cv_5...
# 15  Random_Fourier_features_and_SVR_CPU_SMALL_cv_5...
# 16  Random_Fourier_features_and_SVR_CPU_SMALL_cv_5...
# 17  Random_Fourier_features_and_SVR_CPU_SMALL_cv_5...
# 18  Random_Fourier_features_and_SVR_CPU_SMALL_cv_5...
# 19  Random_Fourier_features_and_SVR_CPU_SMALL_cv_5...
# 20  Random_Fourier_features_and_SVR_CPU_SMALL_cv_5...
# 21  Random_Fourier_features_and_SVR_CPU_SMALL_cv_5...
# 22  Random_Fourier_features_and_SVR_CPU_SMALL_cv_5...
# 23  Random_Fourier_features_and_SVR_CPU_SMALL_cv_5...
# 24  Random_Fourier_features_and_SVR_CPU_SMALL_cv_5...

# %%
def show_dataframe( dataframe, column, ascending = True, decimals = 3, only_relevant_columns = True):
      dataframe =  pd.DataFrame(dataframe).round(decimals).sort_values(by=column, ascending= ascending)

      if only_relevant_columns:
            dataframe = dataframe[["File","percent", column, "n_components" ]]
   
      return dataframe
score_column = ridge_data.columns[2]
time_column = ridge_data.columns[4]
name_column = 'File'

# %% [markdown]
# # Sort by score

# %%
show_dataframe(ridge_data, score_column, ascending=False)
# Out:
#                                                  File  percent  \
# 11    Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv   19.995
# 10    Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv   17.993
# 8     Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv   13.989
# 12    Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv   25.000
# 7     Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv    9.998
# 9     Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv   15.991
# 0          Kernel_ridge_regression_CPU_SMALL_cv_5.csv  100.000
# 4     Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv    3.992
# 6     Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv    7.996
# 5     Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv    5.994
# 23  Random_Fourier_features_and_ridge_regression_C...   19.995
# 21  Random_Fourier_features_and_ridge_regression_C...   15.991
# 24  Random_Fourier_features_and_ridge_regression_C...   25.000
# 20  Random_Fourier_features_and_ridge_regression_C...   13.989
# 19  Random_Fourier_features_and_ridge_regression_C...    9.998
# 2     Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv    0.989
# 17  Random_Fourier_features_and_ridge_regression_C...    5.994
# 3     Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv    1.990
# 18  Random_Fourier_features_and_ridge_regression_C...    7.996
# 16  Random_Fourier_features_and_ridge_regression_C...    3.992
# 15  Random_Fourier_features_and_ridge_regression_C...    1.990
# 22  Random_Fourier_features_and_ridge_regression_C...   17.993
# 1     Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv    0.488
# 13  Random_Fourier_features_and_ridge_regression_C...    0.488
# 14  Random_Fourier_features_and_ridge_regression_C...    0.989
#
#     Mean Score in test  n_components
# 11               0.973          1638
# 10               0.973          1474
# 8                0.973          1146
# 12               0.972          2048
# 7                0.972           819
# 9                0.972          1310
# 0                0.971          8192
# 4                0.971           327
# 6                0.970           655
# 5                0.970           491
# 23               0.969          1638
# 21               0.969          1310
# 24               0.969          2048
# 20               0.967          1146
# 19               0.965           819
# 2                0.964            81
# 17               0.963           491
# 3                0.959           163
# 18               0.956           655
# 16               0.951           327
# 15               0.949           163
# 22               0.923          1474
# 1                0.898            40
# 13               0.853            40
# 14               0.664            81

# %% [markdown]
# # Damping

# %%
show_dataframe(ridge_data, damping_column, ascending=False)
# Out:
#                                                  File  percent   damping  \
# 13  Random_Fourier_features_and_ridge_regression_C...    0.488  3813.106
# 1     Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv    0.488  2788.984
# 2     Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv    0.989  1628.004
# 14  Random_Fourier_features_and_ridge_regression_C...    0.989  1608.944
# 15  Random_Fourier_features_and_ridge_regression_C...    1.990  1098.053
# 3     Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv    1.990   767.251
# 16  Random_Fourier_features_and_ridge_regression_C...    3.992   577.080
# 17  Random_Fourier_features_and_ridge_regression_C...    5.994   357.239
# 4     Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv    3.992   336.552
# 18  Random_Fourier_features_and_ridge_regression_C...    7.996   238.794
# 5     Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv    5.994   203.447
# 19  Random_Fourier_features_and_ridge_regression_C...    9.998   193.811
# 6     Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv    7.996   123.974
# 20  Random_Fourier_features_and_ridge_regression_C...   13.989   119.705
# 21  Random_Fourier_features_and_ridge_regression_C...   15.991   102.527
# 22  Random_Fourier_features_and_ridge_regression_C...   17.993    83.100
# 7     Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv    9.998    82.094
# 23  Random_Fourier_features_and_ridge_regression_C...   19.995    74.896
# 24  Random_Fourier_features_and_ridge_regression_C...   25.000    50.430
# 8     Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv   13.989    42.685
# 9     Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv   15.991    32.065
# 10    Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv   17.993    24.643
# 11    Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv   19.995    18.204
# 0          Kernel_ridge_regression_CPU_SMALL_cv_5.csv  100.000    18.047
# 12    Nystrom_and_ridge_regression_CPU_SMALL_cv_5.csv   25.000     9.021
#
#     n_components
# 13            40
# 1             40
# 2             81
# 14            81
# 15           163
# 3            163
# 16           327
# 17           491
# 4            327
# 18           655
# 5            491
# 19           819
# 6            655
# 20          1146
# 21          1310
# 22          1474
# 7            819
# 23          1638
# 24          2048
# 8           1146
# 9           1310
# 10          1474
# 11          1638
# 0           8192
# 12          2048

# %% [markdown]
# # Plotting
# ## Ridge

# %%
from plotting import view_plots_and_save_them


columns = [score_column, time_column, damping_column ]
  
view_plots_and_save_them(df_list = ridge_list, df_list_names=ridge_list_names, type ='ridge',
                          columns=columns, database=database, plot_path = plot_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/6x/92l244517zjbjbndy62lk_9m0000gn/T/ipykernel_6980/4133542639.py in <module>
# ----> 1 from plotting import view_plots_and_save_them
#       2
#       3
#       4 columns = [score_column, time_column, damping_column ]
#       5
#
# ModuleNotFoundError: No module named 'plotting'

# %% [markdown]
# ## SVM

# %%
view_plots_and_save_them(df_list = svm_list, df_list_names=svm_list_names, type ='svm',
                          columns=columns, database=database, plot_path = plot_path)

# %% [markdown]
# # Hyperparameter

# %%
print(svm_data_verbose )
