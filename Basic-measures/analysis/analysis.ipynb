# %%
import pandas as pd
import numpy as np

df_nn = pd.read_csv('/Users/blancacanocamarero/repositorios/TFM/Kernel-methods-comparatives/Basic-measures/results/accuracy_time_stats/neural_network_classification_a9a_cv_5.txt')
df_nystrom_and_ridge = pd.read_csv('/Users/blancacanocamarero/repositorios/TFM/Kernel-methods-comparatives/Basic-measures/results/accuracy_time_stats/Nystrom_and_ridge_classification_a9a_cv_5.txt')
df_rbf_and_ridge = pd.read_csv('/Users/blancacanocamarero/repositorios/TFM/Kernel-methods-comparatives/Basic-measures/results/accuracy_time_stats/RBF_and_ridge_classification_a9a_cv_5.txt')

# %%
np.sqrt(20000)
# Out:
# 141.4213562373095

# %%
nn_accuracy = df_nn.accuracy_test.to_list()
nn_training_time = df_nn.training_time.to_list()
nn_labels = list(map(lambda x: 'NN of shape '+str(x),df_nn.hidden_layer_sizes.to_list()))
df_nn.head()
# Out:
#   hidden_layer_sizes                         best_params  best_accuracy_cv  \
# 0           (20000,)  {'mlp_classification__alpha': 1.0}          0.848838
# 1         (141, 141)  {'mlp_classification__alpha': 1.0}          0.846811
# 2       (27, 27, 27)  {'mlp_classification__alpha': 1.0}          0.847271
#
#    training_time  accuracy_test  \
# 0     978.511512       0.851053
# 1      35.615685       0.846570
# 2      19.370672       0.847430
#
#                                        mean_fit_time  \
# 0  [2236.79129443 2595.93281002 2392.84557304 341...
# 1  [55.01855102 71.25109944 55.6065217  55.040335...
# 2  [68.75050168 74.73460937 78.78191433 86.511458...
#
#                                         std_fit_time  \
# 0  [5.13519161e+02 2.31519180e+02 5.46123320e+02 ...
# 1  [ 6.44965726 12.44416741 12.56136274  8.351517...
# 2  [ 2.6066683  10.79266137 12.74077879 21.580773...
#
#                                      mean_score_time  \
# 0  [ 1.7891417   1.88607588  1.92689934  1.833892...
# 1  [0.03813205 0.03819232 0.03580923 0.03631101 0...
# 2  [0.01696496 0.01680293 0.01698532 0.01740627 0...
#
#                                       std_score_time  \
# 0  [0.11530421 0.0825361  0.12113651 0.49848852 0...
# 1  [0.00155204 0.0013802  0.00354309 0.00115906 0...
# 2  [4.94780316e-04 1.13862328e-03 8.99482334e-04 ...
#
#                      param_mlp_classification__alpha  \
# 0  [1e-06 1e-05 0.0001 0.001 0.01 0.1 1.0 10.0 10...
# 1  [1e-06 1e-05 0.0001 0.001 0.01 0.1 1.0 10.0 10...
# 2  [1e-06 1e-05 0.0001 0.001 0.01 0.1 1.0 10.0 10...
#
#                                               params  \
# 0  [{'mlp_classification__alpha': 1e-06}, {'mlp_c...
# 1  [{'mlp_classification__alpha': 1e-06}, {'mlp_c...
# 2  [{'mlp_classification__alpha': 1e-06}, {'mlp_c...
#
#                                    split0_test_score  \
# 0  [0.80561953 0.81145402 0.80623369 0.80577307 0...
# 1  [0.8039306  0.80270229 0.80377706 0.8031629  0...
# 2  [0.80178105 0.79886381 0.80224167 0.8011669  0...
#
#                                    split1_test_score  \
# 0  [0.81572482 0.81649263 0.82171376 0.81587838 0...
# 1  [0.80850737 0.80190418 0.80850737 0.80666462 0...
# 2  [0.79821867 0.80620393 0.80451474 0.80251843 0...
#
#                                    split2_test_score  \
# 0  [0.81864251 0.82294226 0.81464988 0.81695332 0...
# 1  [0.80328624 0.81511057 0.81557125 0.81280713 0...
# 2  [0.81065725 0.81050369 0.80942875 0.80835381 0...
#
#                                    split3_test_score  \
# 0  [0.81787469 0.81726044 0.82355651 0.82094595 0...
# 1  [0.81679975 0.80973587 0.81142506 0.81480344 0...
# 2  [0.81234644 0.81142506 0.81357494 0.81173219 0...
#
#                                    split4_test_score  \
# 0  [0.8227887  0.81971744 0.81603194 0.82017813 0...
# 1  [0.81649263 0.81265356 0.81679975 0.8112715  0...
# 2  [0.80973587 0.81188575 0.81434275 0.81035012 0...
#
#                                      mean_test_score  \
# 0  [0.81613005 0.81757336 0.81643715 0.81594577 0...
# 1  [0.80980332 0.80842129 0.8112161  0.80974192 0...
# 2  [0.80654786 0.80777645 0.80882057 0.80682429 0...
#
#                                       std_test_score  \
# 0  [5.73287095e-03 3.79827516e-03 6.09913294e-03 ...
# 1  [5.87090435e-03 5.28330218e-03 4.75109942e-03 ...
# 2  [5.52759968e-03 4.88967223e-03 4.80188432e-03 ...
#
#                  rank_test_score
# 0  [7 5 6 8 4 3 1 2 9 9 9 9 9 9]
# 1  [6 8 5 7 4 3 1 2 9 9 9 9 9 9]
# 2  [8 6 5 7 4 3 1 2 9 9 9 9 9 9]

# %%
nn_accuracy,nn_training_time,nn_labels
# Out:
# ([0.8510533750998096, 0.8465696210306493, 0.8474295190713101],
#  [978.511512041092, 35.615684509277344, 19.37067198753357],
#  ['NN of shape (20000,)',
#   'NN of shape (141, 141)',
#   'NN of shape (27, 27, 27)'])

# %%
df_nystrom_and_ridge
# Out:
#    n_components                                        best_params  \
# 0            10  {'nystroem__gamma': 8.982555655316915e-05, 'ri...
# 1            20  {'nystroem__gamma': 8.982555655316915e-05, 'ri...
# 2            50  {'nystroem__gamma': 8.982555655316915e-05, 'ri...
# 3           100  {'nystroem__gamma': 8.982555655316915e-05, 'ri...
# 4           200  {'nystroem__gamma': 0.0010162601626016261, 'ri...
# 5           500  {'nystroem__gamma': 8.982555655316915e-05, 'ri...
# 6          1000  {'nystroem__gamma': 8.982555655316915e-05, 'ri...
#
#    best_accuracy_cv  training_time  accuracy_test  \
# 0          0.804705       0.214731       0.791045
# 1          0.820921       0.194165       0.819483
# 2          0.842572       0.336913       0.844051
# 3          0.844753       0.488412       0.847000
# 4          0.846964       0.733879       0.848412
# 5          0.848653       1.563415       0.849518
# 6          0.849913       3.150516       0.849825
#
#                                        mean_fit_time  \
# 0  [0.40245018 0.18587227 0.19280739 0.19285541 0...
# 1  [0.2161047  0.1994832  0.22125235 0.19500098 0...
# 2  [0.43932533 0.30535936 0.30646429 0.29153047 0...
# 3  [0.44368949 0.39108872 0.38002138 0.40070324 0...
# 4  [0.80914388 0.74147582 0.69521651 0.6677309  0...
# 5  [1.85326204 1.70190868 1.74956841 1.76818762 1...
# 6  [4.32920403 4.17040038 4.140346   4.17815032 4...
#
#                                         std_fit_time  \
# 0  [0.02936666 0.0337309  0.02375158 0.02309609 0...
# 1  [0.02619369 0.01120055 0.02501412 0.00838538 0...
# 2  [0.04530008 0.06755624 0.03962683 0.02941914 0...
# 3  [0.04477589 0.04245373 0.02863836 0.02105613 0...
# 4  [0.0568825  0.05649802 0.0370215  0.02520194 0...
# 5  [0.1011576  0.08724273 0.0807284  0.06497235 0...
# 6  [0.1418406  0.12400237 0.1309089  0.08131341 0...
#
#                                      mean_score_time  \
# 0  [0.01772885 0.01431069 0.01334543 0.01284113 0...
# 1  [0.01602602 0.01617551 0.01776142 0.01482787 0...
# 2  [0.02690043 0.02952704 0.03103886 0.02647533 0...
# 3  [0.05939336 0.05439606 0.0548233  0.06647878 0...
# 4  [0.08547859 0.09702606 0.0862771  0.07578812 0...
# 5  [0.23922496 0.23511329 0.23797674 0.23845315 0...
# 6  [0.62074647 0.59565105 0.61534386 0.57635512 0...
#
#                                       std_score_time  \
# 0  [0.00244025 0.00229279 0.00165606 0.00177121 0...
# 1  [0.00207999 0.00174954 0.00114002 0.0009155  0...
# 2  [0.00391201 0.00627274 0.01094076 0.00459984 0...
# 3  [0.00911113 0.00968613 0.00536752 0.01718664 0...
# 4  [0.01461002 0.01476332 0.00924246 0.01052    0...
# 5  [0.02774126 0.02300131 0.02394725 0.00909078 0...
# 6  [0.06305236 0.04352521 0.07042411 0.04407967 0...
#
#                                param_nystroem__gamma  \
# 0  [7.939532520325204e-06 7.939532520325204e-06 7...
# 1  [7.939532520325204e-06 7.939532520325204e-06 7...
# 2  [7.939532520325204e-06 7.939532520325204e-06 7...
# 3  [7.939532520325204e-06 7.939532520325204e-06 7...
# 4  [7.939532520325204e-06 7.939532520325204e-06 7...
# 5  [7.939532520325204e-06 7.939532520325204e-06 7...
# 6  [7.939532520325204e-06 7.939532520325204e-06 7...
#
#                    param_ridge_classification__alpha  \
# 0  [0.0001 0.0017782794100389228 0.03162277660168...
# 1  [0.0001 0.0017782794100389228 0.03162277660168...
# 2  [0.0001 0.0017782794100389228 0.03162277660168...
# 3  [0.0001 0.0017782794100389228 0.03162277660168...
# 4  [0.0001 0.0017782794100389228 0.03162277660168...
# 5  [0.0001 0.0017782794100389228 0.03162277660168...
# 6  [0.0001 0.0017782794100389228 0.03162277660168...
#
#                                               params  \
# 0  [{'nystroem__gamma': 7.939532520325204e-06, 'r...
# 1  [{'nystroem__gamma': 7.939532520325204e-06, 'r...
# 2  [{'nystroem__gamma': 7.939532520325204e-06, 'r...
# 3  [{'nystroem__gamma': 7.939532520325204e-06, 'r...
# 4  [{'nystroem__gamma': 7.939532520325204e-06, 'r...
# 5  [{'nystroem__gamma': 7.939532520325204e-06, 'r...
# 6  [{'nystroem__gamma': 7.939532520325204e-06, 'r...
#
#                                    split0_test_score  \
# 0  [0.77076616 0.77583295 0.79272225 0.75541225 0...
# 1  [0.81206817 0.81529249 0.81713496 0.79379702 0...
# 2  [0.83555965 0.84001228 0.84492553 0.82373714 0...
# 3  [0.84108706 0.8404729  0.84139413 0.82803624 0...
# 4  [0.84031936 0.84216183 0.84139413 0.82880393 0...
# 5  [0.84369722 0.84170121 0.84139413 0.82880393 0...
# 6  [0.84431138 0.84170121 0.84170121 0.82880393 0...
#
#                                    split1_test_score  \
# 0  [0.76443489 0.77533784 0.78025184 0.75844595 0...
# 1  [0.82417076 0.81848894 0.80973587 0.79084767 0...
# 2  [0.84305897 0.84213759 0.84075553 0.82539926 0...
# 3  [0.84597666 0.84290541 0.84551597 0.82724201 0...
# 4  [0.84490172 0.84428747 0.84490172 0.82724201 0...
# 5  [0.84689803 0.84398034 0.84459459 0.82785627 0...
# 6  [0.84751229 0.84428747 0.84490172 0.82816339 0...
#
#                                    split2_test_score  \
# 0  [0.814957   0.80144349 0.81203931 0.80297912 0...
# 1  [0.81526413 0.81649263 0.81557125 0.78316953 0...
# 2  [0.84244472 0.84367322 0.84075553 0.82693489 0...
# 3  [0.84259828 0.84444103 0.84536241 0.82831695 0...
# 4  [0.84643735 0.84659091 0.8470516  0.82923833 0...
# 5  [0.84643735 0.84720516 0.84720516 0.82939189 0...
# 6  [0.84751229 0.84720516 0.8470516  0.82939189 0...
#
#                                    split3_test_score  \
# 0  [0.81111794 0.80251843 0.77288084 0.76566339 0...
# 1  [0.82463145 0.82386364 0.82048526 0.8046683  0...
# 2  [0.83691646 0.83845209 0.84014128 0.82217445 0...
# 3  [0.84428747 0.84336609 0.83937346 0.83138821 0...
# 4  [0.84536241 0.84305897 0.84183047 0.83169533 0...
# 5  [0.8458231  0.84367322 0.84336609 0.83200246 0...
# 6  [0.84751229 0.84444103 0.84305897 0.83184889 0...
#
#                                    split4_test_score  \
# 0  [0.78055897 0.79883292 0.81219287 0.75537469 0...
# 1  [0.81603194 0.8240172  0.82309582 0.79714373 0...
# 2  [0.84029484 0.84398034 0.84183047 0.82816339 0...
# 3  [0.84643735 0.84351966 0.84213759 0.83108108 0...
# 4  [0.84474816 0.84551597 0.84367322 0.83292383 0...
# 5  [0.84874079 0.84551597 0.84413391 0.83246314 0...
# 6  [0.84843366 0.84536241 0.84367322 0.83215602 0...
#
#                                      mean_test_score  \
# 0  [0.78836699 0.79079313 0.79401742 0.76757508 0...
# 1  [0.81843329 0.81963098 0.81720463 0.79392525 0...
# 2  [0.83965493 0.84165111 0.84168167 0.82528183 0...
# 3  [0.84407736 0.84294102 0.84275671 0.8292129  0...
# 4  [0.8443538  0.84432303 0.84377023 0.82998069 0...
# 5  [0.8463193  0.84441518 0.84413878 0.83010354 0...
# 6  [0.84705638 0.84459946 0.84407734 0.83007283 0...
#
#                                       std_test_score  \
# 0  [2.08237085e-02 1.24757692e-02 1.60814150e-02 ...
# 1  [5.05293114e-03 3.66415803e-03 4.55903044e-03 ...
# 2  [2.96817791e-03 2.12933847e-03 1.71073533e-03 ...
# 3  [2.01745424e-03 1.33104664e-03 2.37020881e-03 ...
# 4  [2.10194601e-03 1.60226617e-03 2.07198262e-03 ...
# 5  [1.63303284e-03 1.84937463e-03 1.88364525e-03 ...
# 6  [1.41813194e-03 1.78292086e-03 1.80954041e-03 ...
#
#                                      rank_test_score
# 0  [11  9  6 19 25 10  1  8  4 17  2  5  7  3 14 ...
# 1  [ 6  4  7 18 25  1  9  5  8 19  3 11 12 10  2 ...
# 2  [ 7  3  2 14 23  4  1  9 10 19  8  5 11  6 12 ...
# 3  [ 3  7  8 18 25  2  1  4 10 19  5  9 12  6 11 ...
# 4  [ 7  8 10 18 25  2  3  6 11 19  1  4  9  5 12 ...
# 5  [ 6  9 10 18 25  1  3  8 11 19  5  4  2  7 12 ...
# 6  [ 6  9 10 18 25  1  5  8 11 19  4  2  3  7 12 ...

# %%
df_rbf_and_ridge
# Out:
#    n_components                                        best_params  \
# 0            10  {'rbf_sampler__gamma': 7.939532520325204e-06, ...
# 1            20  {'rbf_sampler__gamma': 0.0010162601626016261, ...
# 2            50  {'rbf_sampler__gamma': 7.939532520325204e-06, ...
# 3           100  {'rbf_sampler__gamma': 7.939532520325204e-06, ...
# 4           200  {'rbf_sampler__gamma': 7.939532520325204e-06, ...
# 5           500  {'rbf_sampler__gamma': 8.982555655316915e-05, ...
# 6          1000  {'rbf_sampler__gamma': 8.982555655316915e-05, ...
#
#    best_accuracy_cv  training_time  accuracy_test  \
# 0          0.769079       0.166927       0.771881
# 1          0.785387       0.213646       0.781402
# 2          0.820122       0.257184       0.829003
# 3          0.839870       0.323858       0.840980
# 4          0.844415       0.751943       0.845710
# 5          0.845152       1.556815       0.847675
# 6          0.846012       2.728870       0.847552
#
#                                        mean_fit_time  \
# 0  [0.33110232 0.30677109 0.2948204  0.2624239  0...
# 1  [0.29184012 0.30397606 0.31462312 0.28279867 0...
# 2  [0.39524364 0.3814784  0.37311482 0.34362183 0...
# 3  [0.51455412 0.55973921 0.54396253 0.46041923 0...
# 4  [0.9132781  0.85074062 0.88518939 0.87450199 0...
# 5  [2.77622828 2.79061441 2.78599367 2.53596549 2...
# 6  [5.83007717 5.96908026 6.00054021 5.40147829 5...
#
#                                         std_fit_time  \
# 0  [0.02563751 0.01042194 0.04319076 0.01075192 0...
# 1  [0.00983754 0.00673624 0.01194771 0.02051561 0...
# 2  [0.01620919 0.00989549 0.02044888 0.0205388  0...
# 3  [0.0364174  0.00285384 0.01025099 0.02857184 0...
# 4  [0.0142414  0.02999356 0.02388923 0.02696302 0...
# 5  [0.07786376 0.04016885 0.01570078 0.02154061 0...
# 6  [0.12876835 0.10207734 0.03092105 0.25430151 0...
#
#                                      mean_score_time  \
# 0  [0.02459149 0.02162085 0.01986985 0.01654501 0...
# 1  [0.0188252  0.01821346 0.01882596 0.02699647 0...
# 2  [0.04226322 0.0377533  0.02837734 0.02969513 0...
# 3  [0.06025438 0.05719066 0.06029859 0.06452866 0...
# 4  [0.09454923 0.0903964  0.08671637 0.09693851 0...
# 5  [0.24387751 0.24791789 0.24040527 0.22812843 0...
# 6  [0.47480469 0.47324934 0.47307115 0.48270726 0...
#
#                                       std_score_time  \
# 0  [4.12326029e-05 6.29317759e-03 5.91559111e-03 ...
# 1  [0.0029736  0.00121714 0.00193147 0.00370054 0...
# 2  [0.00284582 0.00736895 0.00268122 0.00608074 0...
# 3  [0.00459076 0.00717663 0.00113067 0.00789477 0...
# 4  [0.00236038 0.00890489 0.01019936 0.00250574 0...
# 5  [0.0073291  0.00931445 0.01316485 0.00827535 0...
# 6  [0.01564483 0.01612171 0.02021745 0.02121582 0...
#
#                             param_rbf_sampler__gamma  \
# 0  [7.939532520325204e-06 7.939532520325204e-06 7...
# 1  [7.939532520325204e-06 7.939532520325204e-06 7...
# 2  [7.939532520325204e-06 7.939532520325204e-06 7...
# 3  [7.939532520325204e-06 7.939532520325204e-06 7...
# 4  [7.939532520325204e-06 7.939532520325204e-06 7...
# 5  [7.939532520325204e-06 7.939532520325204e-06 7...
# 6  [7.939532520325204e-06 7.939532520325204e-06 7...
#
#                    param_ridge_classification__alpha  \
# 0  [0.0001 0.0031622776601683794 0.1 3.1622776601...
# 1  [0.0001 0.0031622776601683794 0.1 3.1622776601...
# 2  [0.0001 0.0031622776601683794 0.1 3.1622776601...
# 3  [0.0001 0.0031622776601683794 0.1 3.1622776601...
# 4  [0.0001 0.0031622776601683794 0.1 3.1622776601...
# 5  [0.0001 0.0031622776601683794 0.1 3.1622776601...
# 6  [0.0001 0.0031622776601683794 0.1 3.1622776601...
#
#                                               params  \
# 0  [{'rbf_sampler__gamma': 7.939532520325204e-06,...
# 1  [{'rbf_sampler__gamma': 7.939532520325204e-06,...
# 2  [{'rbf_sampler__gamma': 7.939532520325204e-06,...
# 3  [{'rbf_sampler__gamma': 7.939532520325204e-06,...
# 4  [{'rbf_sampler__gamma': 7.939532520325204e-06,...
# 5  [{'rbf_sampler__gamma': 7.939532520325204e-06,...
# 6  [{'rbf_sampler__gamma': 7.939532520325204e-06,...
#
#                                    split0_test_score  \
# 0  [0.76830953 0.77967143 0.76093966 0.75694764 0...
# 1  [0.77644711 0.79180101 0.78489175 0.75879011 0...
# 2  [0.81820973 0.82865039 0.82373714 0.75817596 0...
# 3  [0.84154767 0.83586673 0.83079994 0.75940427 0...
# 4  [0.84093352 0.84154767 0.83448488 0.76554583 0...
# 5  [0.84108706 0.84170121 0.83863043 0.76001842 0...
# 6  [0.84216183 0.84154767 0.8404729  0.76140028 0...
#
#                                    split1_test_score  \
# 0  [0.75629607 0.76980958 0.75875307 0.75875307 0...
# 1  [0.79407248 0.76259214 0.75307125 0.75737101 0...
# 2  [0.81111794 0.814957   0.81787469 0.76044226 0...
# 3  [0.83814496 0.8379914  0.82432432 0.75752457 0...
# 4  [0.84244472 0.84428747 0.83860565 0.76305283 0...
# 5  [0.84474816 0.84474816 0.84060197 0.76213145 0...
# 6  [0.84643735 0.84367322 0.84275184 0.76182432 0...
#
#                                    split2_test_score  \
# 0  [0.74969287 0.77395577 0.754914   0.75829238 0...
# 1  [0.76750614 0.76581695 0.78209459 0.76013514 0...
# 2  [0.82847052 0.817414   0.81480344 0.75752457 0...
# 3  [0.83998771 0.84766585 0.82800983 0.75982801 0...
# 4  [0.84659091 0.84766585 0.83768428 0.76197789 0...
# 5  [0.84520885 0.8470516  0.84321253 0.76121007 0...
# 6  [0.84766585 0.84781941 0.84382678 0.76090295 0...
#
#                                    split3_test_score  \
# 0  [0.76213145 0.76412776 0.77272727 0.75798526 0...
# 1  [0.78608722 0.79084767 0.75552826 0.7578317  0...
# 2  [0.81756757 0.82109951 0.81188575 0.76074939 0...
# 3  [0.83768428 0.83860565 0.83292383 0.75952088 0...
# 4  [0.84321253 0.84336609 0.84121622 0.7664312  0...
# 5  [0.84474816 0.84428747 0.84152334 0.75998157 0...
# 6  [0.84720516 0.84413391 0.84029484 0.7615172  0...
#
#                                    split4_test_score  \
# 0  [0.75337838 0.7578317  0.75399263 0.75982801 0...
# 1  [0.76167076 0.78624079 0.75307125 0.75721744 0...
# 2  [0.80942875 0.81848894 0.80712531 0.75875307 0...
# 3  [0.84198403 0.83522727 0.83338452 0.76228501 0...
# 4  [0.84413391 0.84520885 0.84351966 0.76812039 0...
# 5  [0.84659091 0.84505528 0.84566953 0.76182432 0...
# 6  [0.84536241 0.84505528 0.84398034 0.76182432 0...
#
#                                      mean_test_score  \
# 0  [0.75796166 0.76907925 0.76026533 0.75836127 0...
# 1  [0.77715674 0.77945971 0.76573142 0.75826908 0...
# 2  [0.8169589  0.82012197 0.81508527 0.75912905 0...
# 3  [0.83986973 0.83907138 0.82988849 0.75971255 0...
# 4  [0.84346312 0.84441519 0.83910213 0.76502563 0...
# 5  [0.84447663 0.84456874 0.84192756 0.76103317 0...
# 6  [0.84576652 0.8444459  0.84226534 0.76149381 0...
#
#                                       std_test_score  \
# 0  [6.58208376e-03 7.58330759e-03 6.72346817e-03 ...
# 1  [1.18266562e-02 1.26381653e-02 1.45570336e-02 ...
# 2  [6.71226384e-03 4.69821872e-03 5.59129901e-03 ...
# 3  [1.73497619e-03 4.47872947e-03 3.36914196e-03 ...
# 4  [1.88318063e-03 2.02663410e-03 3.08414432e-03 ...
# 5  [1.82444385e-03 1.71670137e-03 2.38516929e-03 ...
# 6  [1.96388560e-03 2.04186238e-03 1.59447368e-03 ...
#
#                                      rank_test_score
# 0  [25  1  8 23 12 19  4 18  5 22  2 24  9  6  7 ...
# 1  [ 5  3 15 25 18 10  6  4 12 24  2  1 14  8 17 ...
# 2  [ 2  1  4 25 18  6 10  5 11 24  7  8  3  9 17 ...
# 3  [ 1  3 10 18 19  2  4  5 11 19  7  6  9  8 17 ...
# 4  [ 5  1 10 18 19  2  4  3 11 19  7  6  8  9 17 ...
# 5  [ 3  2  9 18 22  8  1  4 12 22  7 10  5  6 17 ...
# 6  [ 2  6 10 19 22  7  1  3 12 22  8  9  4  5 17 ...

# %%
# %cat /Users/blancacanocamarero/repositorios/TFM/Kernel-methods-comparatives/Basic-measures/results/accuracy_time_stats/KSVM_classification_a9a_cv_5.txt
# Out:
# --------------------
# 'Model: KSVM classification
# 	Dataset: a9a 	CV: 5 	n_jobs: 15
# 	 params: {'svm__C': array([1.00000000e-02, 3.16227766e-01, 1.00000000e+01, 3.16227766e+02,
#        1.00000000e+04]), 'svm__gamma': array([7.93953252e-06, 8.98255566e-05, 1.01626016e-03, 1.14976712e-02,
#        1.30081301e-01])}
# --------------------
# Best Parameters: {'svm__C': 316.22776601683796, 'svm__gamma': 8.982555655316915e-05}
# Best Accuracy in CV: 0.8478242107733125
# Training Time: 59.80529022216797
# Accuracy in test: {0.850991953811191}
# {'mean_fit_time': array([ 144.17499275,  147.10329089,  149.33358665,  157.16480136,
#         375.4540956 ,  146.52034273,  137.05422831,  119.55648799,
#         134.71825686,  594.20466995,  123.01294684,  107.27291698,
#         124.63260789,  446.30966196,  770.85540252,  109.24715605,
#         132.85043211,  380.180092  , 1136.26963158,  733.80241685,
#         170.37127666,  587.40181584, 2596.25093575, 1262.14613352,
#         772.64163442]), 'std_fit_time': array([ 0.68556129,  0.47825475,  0.74405292,  0.46858185,  0.72589281,
#         0.40142492,  0.5975137 ,  1.5880441 ,  4.35017345,  1.26175154,
#         0.45114419,  4.98989711,  0.81393402,  4.23272811,  1.20519394,
#         1.50187488,  1.03832089, 11.15533978, 41.03993818,  2.62975216,
#         0.91991067, 17.47462238, 55.71486925, 62.16788299,  5.91112792]), 'mean_score_time': array([31.67326746, 31.92855849, 31.96013398, 31.22998676, 56.28201041,
#        30.4919879 , 32.77384663, 25.49466391, 29.78071527, 60.82882867,
#        28.71741056, 25.21247435, 26.17790089, 29.04268813, 56.07257695,
#        24.0949275 , 24.57306542, 25.05276222, 28.6915751 , 50.85577679,
#        23.57638164, 21.84873109,  9.24249916, 15.9822226 , 55.83065252]), 'std_score_time': array([0.554055  , 0.32963334, 0.8240744 , 0.30992569, 0.34768775,
#        0.43191498, 1.11024001, 1.2325448 , 0.39612217, 0.88807365,
#        1.1967312 , 1.29092197, 0.44536856, 0.45231175, 2.94565298,
#        0.44783728, 1.2912532 , 1.37342179, 3.44820693, 0.79416535,
#        0.71948515, 1.31039736, 0.9122802 , 0.4440355 , 3.31123057]), 'param_svm__C': masked_array(data=[0.01, 0.01, 0.01, 0.01, 0.01, 0.31622776601683794,
#                    0.31622776601683794, 0.31622776601683794,
#                    0.31622776601683794, 0.31622776601683794, 10.0, 10.0,
#                    10.0, 10.0, 10.0, 316.22776601683796,
#                    316.22776601683796, 316.22776601683796,
#                    316.22776601683796, 316.22776601683796, 10000.0,
#                    10000.0, 10000.0, 10000.0, 10000.0],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_svm__gamma': masked_array(data=[7.939532520325204e-06, 8.982555655316915e-05,
#                    0.0010162601626016261, 0.011497671238805652,
#                    0.13008130081300814, 7.939532520325204e-06,
#                    8.982555655316915e-05, 0.0010162601626016261,
#                    0.011497671238805652, 0.13008130081300814,
#                    7.939532520325204e-06, 8.982555655316915e-05,
#                    0.0010162601626016261, 0.011497671238805652,
#                    0.13008130081300814, 7.939532520325204e-06,
#                    8.982555655316915e-05, 0.0010162601626016261,
#                    0.011497671238805652, 0.13008130081300814,
#                    7.939532520325204e-06, 8.982555655316915e-05,
#                    0.0010162601626016261, 0.011497671238805652,
#                    0.13008130081300814],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'params': [{'svm__C': 0.01, 'svm__gamma': 7.939532520325204e-06}, {'svm__C': 0.01, 'svm__gamma': 8.982555655316915e-05}, {'svm__C': 0.01, 'svm__gamma': 0.0010162601626016261}, {'svm__C': 0.01, 'svm__gamma': 0.011497671238805652}, {'svm__C': 0.01, 'svm__gamma': 0.13008130081300814}, {'svm__C': 0.31622776601683794, 'svm__gamma': 7.939532520325204e-06}, {'svm__C': 0.31622776601683794, 'svm__gamma': 8.982555655316915e-05}, {'svm__C': 0.31622776601683794, 'svm__gamma': 0.0010162601626016261}, {'svm__C': 0.31622776601683794, 'svm__gamma': 0.011497671238805652}, {'svm__C': 0.31622776601683794, 'svm__gamma': 0.13008130081300814}, {'svm__C': 10.0, 'svm__gamma': 7.939532520325204e-06}, {'svm__C': 10.0, 'svm__gamma': 8.982555655316915e-05}, {'svm__C': 10.0, 'svm__gamma': 0.0010162601626016261}, {'svm__C': 10.0, 'svm__gamma': 0.011497671238805652}, {'svm__C': 10.0, 'svm__gamma': 0.13008130081300814}, {'svm__C': 316.22776601683796, 'svm__gamma': 7.939532520325204e-06}, {'svm__C': 316.22776601683796, 'svm__gamma': 8.982555655316915e-05}, {'svm__C': 316.22776601683796, 'svm__gamma': 0.0010162601626016261}, {'svm__C': 316.22776601683796, 'svm__gamma': 0.011497671238805652}, {'svm__C': 316.22776601683796, 'svm__gamma': 0.13008130081300814}, {'svm__C': 10000.0, 'svm__gamma': 7.939532520325204e-06}, {'svm__C': 10000.0, 'svm__gamma': 8.982555655316915e-05}, {'svm__C': 10000.0, 'svm__gamma': 0.0010162601626016261}, {'svm__C': 10000.0, 'svm__gamma': 0.011497671238805652}, {'svm__C': 10000.0, 'svm__gamma': 0.13008130081300814}], 'split0_test_score': array([0.75909719, 0.75909719, 0.75909719, 0.80454476, 0.75909719,
#        0.75909719, 0.81391064, 0.84246891, 0.83755566, 0.77660064,
#        0.83586673, 0.84308306, 0.84292953, 0.82941809, 0.79425764,
#        0.84339014, 0.84369722, 0.83479195, 0.80024566, 0.79441118,
#        0.84477199, 0.83602027, 0.81698142, 0.79871027, 0.79441118]), 'split1_test_score': array([0.75921376, 0.75921376, 0.75921376, 0.8046683 , 0.75921376,
#        0.75921376, 0.8137285 , 0.84428747, 0.84014128, 0.77886978,
#        0.83860565, 0.84674447, 0.84413391, 0.82847052, 0.79867936,
#        0.84766585, 0.84659091, 0.83568796, 0.80451474, 0.79867936,
#        0.84597666, 0.8404484 , 0.81971744, 0.79990786, 0.79867936]), 'split2_test_score': array([0.75921376, 0.75921376, 0.75921376, 0.80789312, 0.75921376,
#        0.75921376, 0.81081081, 0.84566953, 0.84136978, 0.78424447,
#        0.83998771, 0.84613022, 0.84935504, 0.83399877, 0.7997543 ,
#        0.84613022, 0.84889435, 0.8458231 , 0.80804668, 0.7997543 ,
#        0.8482801 , 0.84935504, 0.82294226, 0.79944717, 0.7997543 ]), 'split3_test_score': array([0.75921376, 0.75921376, 0.75921376, 0.80405405, 0.75921376,
#        0.75921376, 0.81157862, 0.84613022, 0.84229115, 0.78040541,
#        0.83952703, 0.84920147, 0.85027641, 0.83768428, 0.80021499,
#        0.84781941, 0.84981572, 0.84628378, 0.80666462, 0.80021499,
#        0.85058354, 0.85273342, 0.82616708, 0.80251843, 0.80021499]), 'split4_test_score': array([0.75921376, 0.75921376, 0.75921376, 0.80451474, 0.75921376,
#        0.75921376, 0.81464988, 0.84597666, 0.84351966, 0.77779484,
#        0.84060197, 0.84797297, 0.84674447, 0.83584152, 0.79760442,
#        0.84935504, 0.85012285, 0.84444103, 0.80297912, 0.79760442,
#        0.8495086 , 0.84674447, 0.82678133, 0.80052211, 0.79760442]), 'mean_test_score': array([0.75919045, 0.75919045, 0.75919045, 0.805135  , 0.75919045,
#        0.75919045, 0.81293569, 0.84490656, 0.84097551, 0.77958303,
#        0.83891782, 0.84662644, 0.84668787, 0.83308263, 0.79810214,
#        0.84687213, 0.84782421, 0.84140557, 0.80449016, 0.79813285,
#        0.84782418, 0.84506032, 0.82251791, 0.80022117, 0.79813285]), 'std_test_score': array([4.66275915e-05, 4.66275915e-05, 4.66275915e-05, 1.39474614e-03,
#        4.66275915e-05, 4.66275915e-05, 1.47473758e-03, 1.38202781e-03,
#        2.03717353e-03, 2.64598984e-03, 1.65884093e-03, 2.06201968e-03,
#        2.85105257e-03, 3.58682082e-03, 2.12390468e-03, 2.01825756e-03,
#        2.40616478e-03, 5.07851354e-03, 2.74505911e-03, 2.06848504e-03,
#        2.16279263e-03, 6.05226709e-03, 3.74615850e-03, 1.29213026e-03,
#        2.06848504e-03]), 'rank_test_score': array([21, 21, 21, 14, 21, 21, 13,  7,  9, 20, 10,  5,  4, 11, 19,  3,  1,
#         8, 15, 17,  2,  6, 12, 16, 17], dtype=int32)}

# %% [markdown]
# Lelevante information for KNVA
#
# ```
# Training Time: 59.80529022216797
# Accuracy in test: {0.850991953811191}
# ```

# %%
nn_accuracy.append(0.850991953811191)
nn_training_time.append(59.80529022216797)
nn_labels.append('KSVM')

# %%
from plotting import plot_comparatives

# %% [markdown]
# # Time analysis adults data set

# %% [markdown]
# Conclusion: Radom features win.
#
# Use Wilcolxon .

# %%
column = 'training_time'
df_with_n_components = [df_nystrom_and_ridge, df_rbf_and_ridge]
df_labels = ['Nyström and ridge regression', 'RFF and ridge regression']
title = 'Evolution of training time vs n_components for a9a dataset'

plot_comparatives(column=column, df_with_n_components=df_with_n_components, df_labels=df_labels, title=title)
plot_comparatives(column, df_with_n_components, df_labels, title, nn_training_time, nn_labels, False)
plot_comparatives(column, df_with_n_components, df_labels, title, nn_training_time[1:], nn_labels[1:], False)
plot_comparatives(column, df_with_n_components, df_labels, title, nn_training_time[2:-1], nn_labels[2:-1], False)

# TODO separate
# rm nn and add svc linear
# ksvm 
# rr Nystrom + rfb linear 
# usar intelet

# %% [markdown]
# # Accuracy

# %%
column = 'accuracy_test'

df_labels = ['Nyström and ridge regression', 'RFF and ridge regression']
title = 'Evolution of accuracy vs n_components for a9a dataset'
constant_data = nn_accuracy
plot_comparatives(column=column, df_with_n_components=df_with_n_components, df_labels=df_labels, title=title)
plot_comparatives(column, [],[], title, constant_data, nn_labels, False)
plot_comparatives(column, df_with_n_components, df_labels, title, constant_data, nn_labels, False)
plot_comparatives(column, df_with_n_components, df_labels, title, constant_data[1:], nn_labels[1:], False)
plot_comparatives(column, df_with_n_components, df_labels, title, constant_data[2:-1], nn_labels[2:-1], False)

# %% [markdown]
# # Damping
#
#
# Formula:
#
# $$damping = \frac{accuracy}{time} \times 100$$
#
# The bigger the best

# %%
# Computing damping
constant_damping = [acc / time*100 for acc,time in zip(nn_accuracy, nn_training_time)]
damping_column = 'damping'
for df in df_with_n_components:
    df['damping'] = df.accuracy_test / df.training_time * 100

# Plotting

column = damping_column
title = 'Evolution of damping vs n_components for a9a dataset'
constant_data = constant_damping
plot_comparatives(column=column, df_with_n_components=df_with_n_components, df_labels=df_labels, title=title)
plot_comparatives(column, [],[], title, constant_data, nn_labels, False, constant_margin=0.05)
plot_comparatives(column, df_with_n_components, df_labels, title, constant_data, nn_labels, False)
